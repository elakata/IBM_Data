# %% [markdown]
# This is my Jupyter Notebook for the IBM Data Science Capstone Project

# %%
import pandas as pd, numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
